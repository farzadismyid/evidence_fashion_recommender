# %%
import pandas as pd
from datasets import load_dataset

# %%
ds = load_dataset(
    "Marqo/polyvore",
    split="data"
)

df = ds.to_pandas()

print(len(df))
df.head()
# Out:
# ...
# 94096
#                                                image      category  \
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...   Day Dresses
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...         Boots
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      Handbags
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...    Sunglasses
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  Floral Decor
#
#                                             text      item_ID
# 0                    tibi knit long sleeve dress  100002074_1
# 1       michael kors leather over-the-knee boots  100002074_2
# 2  givenchy leather medium antigona duffel black  100002074_3
# 3      bottega veneta acetate leather sunglasses  100002074_4
# 4                              pier imports stem  100002074_5
